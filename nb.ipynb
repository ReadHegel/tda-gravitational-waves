# %%
import numpy as np
import yfinance as yf
import plotly.graph_objects as go
import pandas as pd
from download_data import *

# %%
import  as gd
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 import gudhi as gd
#
# ModuleNotFoundError: No module named 'gudhi'

# %%
data = get_log_returns()
# Out:
# (8446,)
# (8446,)
# (8446,)
# (8446,)

# %%
data
# Out:
#                 ^DJI     ^IXIC     ^GSPC      ^RUT
# Date
# 1992-01-03  0.009131  0.010517  0.004972  0.017541
# 1992-01-06 -0.000437  0.008820 -0.003296  0.011594
# 1992-01-07  0.001468  0.007315 -0.001341  0.007383
# 1992-01-08 -0.000281  0.013244  0.001676  0.011730
# 1992-01-09  0.001746  0.015413 -0.001173  0.012492
# ...              ...       ...       ...       ...
# 2025-07-14  0.001984  0.002659  0.001406  0.006645
# 2025-07-15 -0.009863  0.001814 -0.003964 -0.020060
# 2025-07-16  0.005245  0.002545  0.003189  0.009901
# 2025-07-17  0.005177  0.007457  0.005359  0.011914
# 2025-07-18 -0.003204  0.000479 -0.000090 -0.006084
#
# [8445 rows x 4 columns]

# %%
data = get_data(tickers[1])
# Out:
# /home/hegel/tda-article/tda_financial_time_series_notebook/tda-semester-project/download_data.py:27: FutureWarning:
#
# YF.download() has changed argument auto_adjust default to True
#
# [*********************100%***********************]  1 of 1 completed

# %%
fig = go.Figure(data=[
    go.Candlestick(
        x=data.index,
        open=data['Open'][1:].to_numpy(),
        high=data['High'][1:].to_numpy(),
        low=data['Low'][1:].to_numpy(),
        close=data['Close'][1:].to_numpy(),
        name='S&P 500'
    )
])

fig.update_layout(
    title='Candle Plot – S&P 500',
    xaxis_title='Date',
    yaxis_title='Price (USD)',
    xaxis_rangeslider_visible=False,
    template='plotly_white',
    height=600
)

fig.show()
