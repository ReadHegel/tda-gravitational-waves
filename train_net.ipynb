# %% [markdown]
# # This notebook conducts training of the net with and with out additional betti curve backbone

# %%
from data.generate_datasets import make_gravitational_waves
from pathlib import Path
import numpy as np
from torch.utils.data import Dataset, DataLoader
from sklearn.model_selection import train_test_split
from net import Clasificator, train
import torch.nn.functional as F
import torch 
from pipeline import pipeline_complex, pipeline_embedder

np.random.seed(42)

# %%
R = 0.65
n_signals = 1000
DATA = Path("./data")

noisy_signals, gw_signals, labels = make_gravitational_waves(
    path_to_data=DATA, n_signals=n_signals, r_min=R, r_max=R, n_snr_values=1
)

print(f"Number of noisy signals: {len(noisy_signals)}")
print(f"Number of timesteps per series: {len(noisy_signals[0])}")
# Out:
# Number of noisy signals: 1000
# Number of timesteps per series: 8692

# %% [markdown]
# ### Create dataset. This may take a while, because the topological feateres need to be calculated

# %%
class GravWavesDataSet(Dataset): 
    def __init__(self, noise_signal, labels): 
        self.noise_signal = noise_signal
        self.labels = labels
        self.betti_curves = pipeline_complex.fit_transform(
            pipeline_embedder.fit_transform(
                self.noise_signal
                )
            )
        
    def __len__(self): 
        return len(self.noise_signal)

    def _transform(self, data): 
        data = torch.Tensor(data)

        mean = data.mean()
        std = data.std()
        data = (data - mean) / (std + 1e-8) 

        if len(data.shape) == 1:
            data = data.unsqueeze(0)
            
        return data 

    def __getitem__(self, idx): 
        signal = self._transform(self.noise_signal[idx])
        betti = self._transform(self.betti_curves[idx])
        label = torch.tensor(self.labels[idx], dtype=torch.long)

        return (signal, betti), label
    
X_train, X_test, y_train, y_test = train_test_split(
    np.array(noisy_signals), np.array(labels), test_size=0.1, random_state=42, stratify=labels
) 

train_dataset = GravWavesDataSet(X_train, y_train)
test_dataset = GravWavesDataSet(X_test, y_test)

# %%
train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=32, shuffle=False)

# %% [markdown]
# # Train neural network

# %% [markdown]
# ## Train with betti curve

# %%
model = Clasificator()
optim = torch.optim.Adam(model.parameters())

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f"device: {device}")

train(model, device, train_loader, test_loader, optim, epochs=40)
# Out:
# device: cuda
# Train Epoch: 1 [0/900 (0%)]	Loss: 0.693323
#
# Test set: Average loss: 0.0275, Accuracy: 51/100 (51%)
#
# Train Epoch: 2 [0/900 (0%)]	Loss: 0.691989
#
# Test set: Average loss: 0.0259, Accuracy: 74/100 (74%)
#
# Train Epoch: 3 [0/900 (0%)]	Loss: 0.656152
#
# Test set: Average loss: 0.0112, Accuracy: 84/100 (84%)
#
# Train Epoch: 4 [0/900 (0%)]	Loss: 0.231858
#
# Test set: Average loss: 0.0043, Accuracy: 96/100 (96%)
#
# Train Epoch: 5 [0/900 (0%)]	Loss: 0.375190
#
# Test set: Average loss: 0.0037, Accuracy: 99/100 (99%)
#
# Train Epoch: 6 [0/900 (0%)]	Loss: 0.050065
#
# Test set: Average loss: 0.0039, Accuracy: 98/100 (98%)
#
# Train Epoch: 7 [0/900 (0%)]	Loss: 0.065100
#
# Test set: Average loss: 0.0040, Accuracy: 97/100 (97%)
#
# Train Epoch: 8 [0/900 (0%)]	Loss: 0.354728
#
# Test set: Average loss: 0.0055, Accuracy: 95/100 (95%)
#
# Train Epoch: 9 [0/900 (0%)]	Loss: 0.217233
#
# Test set: Average loss: 0.0033, Accuracy: 98/100 (98%)
#
# Train Epoch: 10 [0/900 (0%)]	Loss: 0.055394
#
# Test set: Average loss: 0.0069, Accuracy: 94/100 (94%)
#
# Train Epoch: 11 [0/900 (0%)]	Loss: 0.118926
#
# Test set: Average loss: 0.0103, Accuracy: 89/100 (89%)
#
# Train Epoch: 12 [0/900 (0%)]	Loss: 0.222103
#
# Test set: Average loss: 0.0049, Accuracy: 96/100 (96%)
#
# Train Epoch: 13 [0/900 (0%)]	Loss: 0.185689
#
# Test set: Average loss: 0.0027, Accuracy: 99/100 (99%)
#
# Train Epoch: 14 [0/900 (0%)]	Loss: 0.170164
#
# Test set: Average loss: 0.0031, Accuracy: 99/100 (99%)
#
# Train Epoch: 15 [0/900 (0%)]	Loss: 0.119966
#
# Test set: Average loss: 0.0025, Accuracy: 99/100 (99%)
#
# Train Epoch: 16 [0/900 (0%)]	Loss: 0.114492
#
# Test set: Average loss: 0.0028, Accuracy: 99/100 (99%)
#
# Train Epoch: 17 [0/900 (0%)]	Loss: 0.136278
#
# Test set: Average loss: 0.0030, Accuracy: 97/100 (97%)
#
# Train Epoch: 18 [0/900 (0%)]	Loss: 0.065727
#
# Test set: Average loss: 0.0057, Accuracy: 96/100 (96%)
#
# Train Epoch: 19 [0/900 (0%)]	Loss: 0.048064
#
# Test set: Average loss: 0.0023, Accuracy: 99/100 (99%)
#
# Train Epoch: 20 [0/900 (0%)]	Loss: 0.067005
#
# Test set: Average loss: 0.0023, Accuracy: 99/100 (99%)
#
# Train Epoch: 21 [0/900 (0%)]	Loss: 0.008255
#
# Test set: Average loss: 0.0023, Accuracy: 99/100 (99%)
#
# Train Epoch: 22 [0/900 (0%)]	Loss: 0.057043
#
# Test set: Average loss: 0.0027, Accuracy: 99/100 (99%)
#
# Train Epoch: 23 [0/900 (0%)]	Loss: 0.028333
#
# Test set: Average loss: 0.0023, Accuracy: 99/100 (99%)
#
# Train Epoch: 24 [0/900 (0%)]	Loss: 0.116021
#
# Test set: Average loss: 0.0030, Accuracy: 98/100 (98%)
#
# Train Epoch: 25 [0/900 (0%)]	Loss: 0.072567
#
# Test set: Average loss: 0.0021, Accuracy: 99/100 (99%)
#
# Train Epoch: 26 [0/900 (0%)]	Loss: 0.039713
#
# Test set: Average loss: 0.0021, Accuracy: 99/100 (99%)
#
# Train Epoch: 27 [0/900 (0%)]	Loss: 0.048771
#
# Test set: Average loss: 0.0073, Accuracy: 90/100 (90%)
#
# Train Epoch: 28 [0/900 (0%)]	Loss: 0.145317
#
# Test set: Average loss: 0.0023, Accuracy: 99/100 (99%)
#
# Train Epoch: 29 [0/900 (0%)]	Loss: 0.070212
#
# Test set: Average loss: 0.0021, Accuracy: 99/100 (99%)
#
# Train Epoch: 30 [0/900 (0%)]	Loss: 0.205358
#
# Test set: Average loss: 0.0026, Accuracy: 98/100 (98%)
#
# Train Epoch: 31 [0/900 (0%)]	Loss: 0.082327
#
# Test set: Average loss: 0.0026, Accuracy: 98/100 (98%)
#
# Train Epoch: 32 [0/900 (0%)]	Loss: 0.201816
#
# Test set: Average loss: 0.0021, Accuracy: 99/100 (99%)
#
# Train Epoch: 33 [0/900 (0%)]	Loss: 0.136652
#
# Test set: Average loss: 0.0020, Accuracy: 99/100 (99%)
#
# Train Epoch: 34 [0/900 (0%)]	Loss: 0.030616
#
# Test set: Average loss: 0.0027, Accuracy: 98/100 (98%)
#
# Train Epoch: 35 [0/900 (0%)]	Loss: 0.046360
#
# Test set: Average loss: 0.0023, Accuracy: 99/100 (99%)
#
# Train Epoch: 36 [0/900 (0%)]	Loss: 0.077340
#
# Test set: Average loss: 0.0021, Accuracy: 99/100 (99%)
#
# Train Epoch: 37 [0/900 (0%)]	Loss: 0.014698
#
# Test set: Average loss: 0.0022, Accuracy: 99/100 (99%)
#
# Train Epoch: 38 [0/900 (0%)]	Loss: 0.035337
#
# Test set: Average loss: 0.0028, Accuracy: 98/100 (98%)
#
# Train Epoch: 39 [0/900 (0%)]	Loss: 0.048868
#
# Test set: Average loss: 0.0021, Accuracy: 99/100 (99%)
#
# Train Epoch: 40 [0/900 (0%)]	Loss: 0.019350
#
# Test set: Average loss: 0.0020, Accuracy: 99/100 (99%)

# %% [markdown]
# # Train without betti curve

# %%
model = Clasificator(with_betti=False)
optim = torch.optim.Adam(model.parameters())

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f"device: {device}")

train(model, device, train_loader, test_loader, optim, epochs=40)
# Out:
# device: cuda
# Train Epoch: 1 [0/900 (0%)]	Loss: 0.693376
#
# Test set: Average loss: 0.0276, Accuracy: 51/100 (51%)
#
# Train Epoch: 2 [0/900 (0%)]	Loss: 0.688309
#
# Test set: Average loss: 0.0277, Accuracy: 51/100 (51%)
#
# Train Epoch: 3 [0/900 (0%)]	Loss: 0.693258
#
# Test set: Average loss: 0.0276, Accuracy: 51/100 (51%)
#
# Train Epoch: 4 [0/900 (0%)]	Loss: 0.688038
#
# Test set: Average loss: 0.0276, Accuracy: 51/100 (51%)
#
# Train Epoch: 5 [0/900 (0%)]	Loss: 0.691832
#
# Test set: Average loss: 0.0277, Accuracy: 51/100 (51%)
#
# Train Epoch: 6 [0/900 (0%)]	Loss: 0.697270
#
# Test set: Average loss: 0.0277, Accuracy: 51/100 (51%)
#
# Train Epoch: 7 [0/900 (0%)]	Loss: 0.692473
#
# Test set: Average loss: 0.0277, Accuracy: 51/100 (51%)
#
# Train Epoch: 8 [0/900 (0%)]	Loss: 0.691366
#
# Test set: Average loss: 0.0276, Accuracy: 51/100 (51%)
#
# Train Epoch: 9 [0/900 (0%)]	Loss: 0.701008
#
# Test set: Average loss: 0.0276, Accuracy: 51/100 (51%)
#
# Train Epoch: 10 [0/900 (0%)]	Loss: 0.696953
#
# Test set: Average loss: 0.0276, Accuracy: 51/100 (51%)
#
# Train Epoch: 11 [0/900 (0%)]	Loss: 0.683702
#
# Test set: Average loss: 0.0276, Accuracy: 51/100 (51%)
#
# Train Epoch: 12 [0/900 (0%)]	Loss: 0.692255
#
# Test set: Average loss: 0.0277, Accuracy: 51/100 (51%)
#
# Train Epoch: 13 [0/900 (0%)]	Loss: 0.693253
#
# Test set: Average loss: 0.0277, Accuracy: 51/100 (51%)
#
# Train Epoch: 14 [0/900 (0%)]	Loss: 0.695394
#
# Test set: Average loss: 0.0276, Accuracy: 51/100 (51%)
#
# Train Epoch: 15 [0/900 (0%)]	Loss: 0.693424
#
# Test set: Average loss: 0.0277, Accuracy: 51/100 (51%)
#
# Train Epoch: 16 [0/900 (0%)]	Loss: 0.690818
#
# Test set: Average loss: 0.0276, Accuracy: 51/100 (51%)
#
# Train Epoch: 17 [0/900 (0%)]	Loss: 0.689874
#
# Test set: Average loss: 0.0277, Accuracy: 51/100 (51%)
#
# Train Epoch: 18 [0/900 (0%)]	Loss: 0.692451
#
# Test set: Average loss: 0.0277, Accuracy: 51/100 (51%)
#
# Train Epoch: 19 [0/900 (0%)]	Loss: 0.695756
#
# Test set: Average loss: 0.0277, Accuracy: 51/100 (51%)
#
# Train Epoch: 20 [0/900 (0%)]	Loss: 0.693663
#
# Test set: Average loss: 0.0277, Accuracy: 51/100 (51%)
#
# Train Epoch: 21 [0/900 (0%)]	Loss: 0.692211
#
# Test set: Average loss: 0.0277, Accuracy: 51/100 (51%)
#
# Train Epoch: 22 [0/900 (0%)]	Loss: 0.694114
#
# Test set: Average loss: 0.0276, Accuracy: 51/100 (51%)
#
# Train Epoch: 23 [0/900 (0%)]	Loss: 0.691131
#
# Test set: Average loss: 0.0276, Accuracy: 51/100 (51%)
#
# Train Epoch: 24 [0/900 (0%)]	Loss: 0.692076
#
# Test set: Average loss: 0.0277, Accuracy: 51/100 (51%)
#
# Train Epoch: 25 [0/900 (0%)]	Loss: 0.692330
#
# Test set: Average loss: 0.0277, Accuracy: 51/100 (51%)
#
# Train Epoch: 26 [0/900 (0%)]	Loss: 0.693160
#
# Test set: Average loss: 0.0276, Accuracy: 51/100 (51%)
#
# Train Epoch: 27 [0/900 (0%)]	Loss: 0.695602
#
# Test set: Average loss: 0.0276, Accuracy: 51/100 (51%)
#
# Train Epoch: 28 [0/900 (0%)]	Loss: 0.692233
#
# Test set: Average loss: 0.0277, Accuracy: 51/100 (51%)
#
# Train Epoch: 29 [0/900 (0%)]	Loss: 0.690629
#
# Test set: Average loss: 0.0277, Accuracy: 51/100 (51%)
#
# Train Epoch: 30 [0/900 (0%)]	Loss: 0.692718
#
# Test set: Average loss: 0.0276, Accuracy: 51/100 (51%)
#
# Train Epoch: 31 [0/900 (0%)]	Loss: 0.694436
#
# Test set: Average loss: 0.0277, Accuracy: 51/100 (51%)
#
# Train Epoch: 32 [0/900 (0%)]	Loss: 0.694273
#
# Test set: Average loss: 0.0277, Accuracy: 51/100 (51%)
#
# Train Epoch: 33 [0/900 (0%)]	Loss: 0.694718
#
# Test set: Average loss: 0.0277, Accuracy: 51/100 (51%)
#
# Train Epoch: 34 [0/900 (0%)]	Loss: 0.691733
#
# Test set: Average loss: 0.0276, Accuracy: 51/100 (51%)
#
# Train Epoch: 35 [0/900 (0%)]	Loss: 0.692146
#
# Test set: Average loss: 0.0277, Accuracy: 51/100 (51%)
#
# Train Epoch: 36 [0/900 (0%)]	Loss: 0.692327
#
# Test set: Average loss: 0.0276, Accuracy: 51/100 (51%)
#
# Train Epoch: 37 [0/900 (0%)]	Loss: 0.693312
#
# Test set: Average loss: 0.0276, Accuracy: 51/100 (51%)
#
# Train Epoch: 38 [0/900 (0%)]	Loss: 0.693334
#
# Test set: Average loss: 0.0276, Accuracy: 51/100 (51%)
#
# Train Epoch: 39 [0/900 (0%)]	Loss: 0.693286
#
# Test set: Average loss: 0.0276, Accuracy: 51/100 (51%)
#
# Train Epoch: 40 [0/900 (0%)]	Loss: 0.693293
#
# Test set: Average loss: 0.0276, Accuracy: 51/100 (51%)
